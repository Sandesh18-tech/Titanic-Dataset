# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandesh18-tech/Titanic-Dataset/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "ID": [1, 2, 3, 4, 5],
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Age": [20, 21, 22, None, 21],
    "Marks": [85, 78, None, 88, 95],
    "City": ["Hyderabad", "Vijayawada", "Visakhapatnam", "Guntur", None]
}

df = pd.DataFrame(data)
df.to_csv("students.csv", index=False)

print(df)
# Out:
#    ID     Name   Age  Marks           City
# 0   1    Alice  20.0   85.0      Hyderabad
# 1   2      Bob  21.0   78.0     Vijayawada
# 2   3  Charlie  22.0    NaN  Visakhapatnam
# 3   4    David   NaN   88.0         Guntur
# 4   5      Eva  21.0   95.0           None

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [20, 21, 22],
    "Marks": [85, 78, 90]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Marks
# 0    Alice   20     85
# 1      Bob   21     78
# 2  Charlie   22     90

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df.head())
# Out:
#    ID     Name   Age  Marks           City
# 0   1    Alice  20.0   85.0      Hyderabad
# 1   2      Bob  21.0   78.0     Vijayawada
# 2   3  Charlie  22.0    NaN  Visakhapatnam
# 3   4    David   NaN   88.0         Guntur
# 4   5      Eva  21.0   95.0            NaN

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df.tail())
# Out:
#    ID     Name   Age  Marks           City
# 0   1    Alice  20.0   85.0      Hyderabad
# 1   2      Bob  21.0   78.0     Vijayawada
# 2   3  Charlie  22.0    NaN  Visakhapatnam
# 3   4    David   NaN   88.0         Guntur
# 4   5      Eva  21.0   95.0            NaN

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df.isnull())
# Out:
#       ID   Name    Age  Marks   City
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False   True  False
# 3  False  False   True  False  False
# 4  False  False  False  False   True

# %%
import pandas as pd

df = pd.read_csv("students.csv")

df = df.fillna(0)
print(df)
# Out:
#    ID     Name   Age  Marks           City
# 0   1    Alice  20.0   85.0      Hyderabad
# 1   2      Bob  21.0   78.0     Vijayawada
# 2   3  Charlie  22.0    0.0  Visakhapatnam
# 3   4    David   0.0   88.0         Guntur
# 4   5      Eva  21.0   95.0              0

# %%
import pandas as pd

df = pd.read_csv("students.csv")

df = df.fillna(df.mean(numeric_only=True))
print(df)
# Out:
#    ID     Name   Age  Marks           City
# 0   1    Alice  20.0   85.0      Hyderabad
# 1   2      Bob  21.0   78.0     Vijayawada
# 2   3  Charlie  22.0   86.5  Visakhapatnam
# 3   4    David  21.0   88.0         Guntur
# 4   5      Eva  21.0   95.0            NaN

# %%
import pandas as pd

df = pd.read_csv("students.csv")

df = df.dropna()
print(df)
# Out:
#    ID   Name   Age  Marks        City
# 0   1  Alice  20.0   85.0   Hyderabad
# 1   2    Bob  21.0   78.0  Vijayawada

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df.describe())
# Out:
#              ID        Age      Marks
# count  5.000000   4.000000   4.000000
# mean   3.000000  21.000000  86.500000
# std    1.581139   0.816497   7.047458
# min    1.000000  20.000000  78.000000
# 25%    2.000000  20.750000  83.250000
# 50%    3.000000  21.000000  86.500000
# 75%    4.000000  21.250000  89.750000
# max    5.000000  22.000000  95.000000

# %%
import pandas as pd

df = pd.read_csv("students.csv")

result = df[df["Marks"] > 80]
print(result)
# Out:
#    ID   Name   Age  Marks       City
# 0   1  Alice  20.0   85.0  Hyderabad
# 3   4  David   NaN   88.0     Guntur
# 4   5    Eva  21.0   95.0        NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Titanic-Dataset.csv")

# Histogram (Age)
plt.figure(figsize=(6,4))
plt.hist(df["Age"].dropna(), bins=20, edgecolor="black")
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
# Bar Chart (Passenger Class)
plt.figure(figsize=(6,4))
df["Pclass"].value_counts().sort_index().plot(kind="bar")
plt.title("Passenger Class Distribution")
plt.xlabel("Pclass")
plt.ylabel("Count")
plt.show()

# %%
# Scatter Plot (Age vs Fare)
plt.figure(figsize=(6,4))
plt.scatter(df["Age"], df["Fare"])
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %%
# Box Plot (Fare)
plt.figure(figsize=(6,4))
plt.boxplot(df["Fare"].dropna())
plt.title("Box Plot of Fare")
plt.ylabel("Fare")
plt.show()

# %%
# Correlation Matrix
print(df.select_dtypes(include=["number"]).corr())
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.select_dtypes(include=["number"]).corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix Heatmap")
plt.show()
